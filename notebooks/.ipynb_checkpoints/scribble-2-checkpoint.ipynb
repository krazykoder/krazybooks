# %%
print ("hello world")
# Out:
# hello world

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV
from pandas import DataFrame as df

# Main settings
epochs = 20
embedding_dim = 50
maxlen = 100
output_file = 'data/output.txt'

# Run grid search for each source (yelp, amazon, imdb)
for source, frame in df.groupby('source'):
    print('Running grid search for data set :', source)
    sentences = df['sentence'].values
    y = df['label'].values

    # Train-test split
    sentences_train, sentences_test, y_train, y_test = train_test_split(
        sentences, y, test_size=0.25, random_state=1000)

    # Tokenize words
    tokenizer = Tokenizer(num_words=5000)
    tokenizer.fit_on_texts(sentences_train)
    X_train = tokenizer.texts_to_sequences(sentences_train)
    X_test = tokenizer.texts_to_sequences(sentences_test)

    # Adding 1 because of reserved 0 index
    vocab_size = len(tokenizer.word_index) + 1

    # Pad sequences with zeros
    X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
    X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

    # Parameter grid for grid search
    param_grid = dict(num_filters=[32, 64, 128],
                      kernel_size=[3, 5, 7],
                      vocab_size=[vocab_size],
                      embedding_dim=[embedding_dim],
                      maxlen=[maxlen])
    model = KerasClassifier(build_fn=create_model,
                            epochs=epochs, batch_size=10,
                            verbose=False)
    grid = RandomizedSearchCV(estimator=model, param_distributions=param_grid,
                              cv=4, verbose=1, n_iter=5)
    grid_result = grid.fit(X_train, y_train)

    # Evaluate testing set
    test_accuracy = grid.score(X_test, y_test)

    # Save and evaluate results
#     prompt = input(f'finished {source}; write to file and proceed? [y/n]')
#     if prompt.lower() not in {'y', 'true', 'yes'}:
#         break
    with open(output_file, 'a') as f:
        s = ('Running {} data set\nBest Accuracy : '
             '{:.4f}\n{}\nTest Accuracy : {:.4f}\n\n')
        output_string = s.format(
            source,
            grid_result.best_score_,
            grid_result.best_params_,
            test_accuracy)
        print(output_string)
        f.write(output_string)

# %% [markdown]
# ## Image from web

# %% [markdown]
# ![hello baby](https://www.livingandloving.co.za/wp-content/uploads/2017/02/How-to-cope-with-your-babys-acid-reflux.jpg)

# %%
! wget https://www.livingandloving.co.za/wp-content/uploads/2017/02/How-to-cope-with-your-babys-acid-reflux.jpg
# Out:
# --2019-01-02 15:17:59--  https://www.livingandloving.co.za/wp-content/uploads/2017/02/How-to-cope-with-your-babys-acid-reflux.jpg
# Resolving www.livingandloving.co.za (www.livingandloving.co.za)... 104.18.34.203, 104.18.35.203
# Connecting to www.livingandloving.co.za (www.livingandloving.co.za)|104.18.34.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 187770 (183K) [image/jpeg]
# Saving to: ‘How-to-cope-with-your-babys-acid-reflux.jpg’
#
# How-to-cope-with-yo 100%[===================>] 183.37K  --.-KB/s    in 0.02s
#
# 2019-01-02 15:18:00 (11.3 MB/s) - ‘How-to-cope-with-your-babys-acid-reflux.jpg’ saved [187770/187770]

# %% [markdown]
# ## PIL - Loading images from from url / web

# %%
from  PIL import Image, ImageEnhance
import requests
from io import BytesIO

# %%
url = "https://www.livingandloving.co.za/wp-content/uploads/2017/02/How-to-cope-with-your-babys-acid-reflux.jpg"

# %%
response = requests.get(url)

img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x500 at 0x7FEFE8F285F8>

# %%
# resize down
factor = 5
imgr = img.resize((int(img.width/factor), int (img.height/factor)),0)
imgr
# Out:
# <PIL.Image.Image image mode=RGB size=150x100 at 0x7FEFEBF5A4E0>

# %%
newimg = ImageEnhance.Contrast(imgr).enhance(5.0)
newimg
# newimg.show(title="hello")
# Out:
# <PIL.Image.Image image mode=RGB size=150x100 at 0x7FEFEBF5AA58>

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.imshow(imgr)
plt.figure()
plt.imshow(newimg)
